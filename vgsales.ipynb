# %% [markdown]
# # Data Analysis Notebook
# This notebook was automatically generated from vgsales.csv
#
# ## Data Overview
# The dataset contains 16599 rows and 11 columns.
#
# ### Column Names:
# - Rank
# - Name
# - Platform
# - Year
# - Genre
# - Publisher
# - NA_Sales
# - EU_Sales
# - JP_Sales
# - Other_Sales
# - Global_Sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# Load the data
df = pd.read_csv('vgsales.csv')
df.head()

# %%
# Basic statistics
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
