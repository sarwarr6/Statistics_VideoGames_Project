# %% [markdown]
# # Data Analysis Notebook
# This notebook was automatically generated from Video Games Sales (1980-2024) - Raw.csv
#
# ## Data Overview
# The dataset contains 64017 rows and 14 columns.
#
# ### Column Names:
# - img
# - title
# - console
# - genre
# - publisher
# - developer
# - critic_score
# - total_sales
# - na_sales
# - jp_sales
# - pal_sales
# - other_sales
# - release_date
# - last_update

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# Load the data
df = pd.read_csv('Video Games Sales (1980-2024) - Raw.csv')
df.head()

# %%
# Basic statistics
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
